# %% [markdown]
# ## Section 2 & 4

# %%
import yfinance as yf
import pandas as pd
from statsmodels.tsa.stattools import grangercausalitytests
import matplotlib.pyplot as plt

# %% [markdown]
# ### Parameters

# %%
coins = ['BTC-USD', 'ETH-USD', 'USDT-USD', 'XRP-USD', 'SOL-USD', 'BNB-USD', 'DOGE-USD', 'USDC-USD', 'ADA-USD', 'TRX-USD']

start_date = '2023-11-01'
end_date = '2024-11-01'

# %% [markdown]
# ### Download Data

# %%
all_data = {}
for coin in coins:
    data = yf.download(coin, start=start_date, end=end_date, interval='1d')
    all_data[coin] = data['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Merge and Store All Data

# %%
Index = None
for coin in all_data.keys():
    Index = all_data[coin].index

x = {coin: data.values.flatten() for coin, data in all_data.items()}
all_data_df = pd.DataFrame(x, index=Index)

# %% [markdown]
# ### Ascending & Descending Volatility

# %%
returns = all_data_df.pct_change()

ascending_volatility = returns[returns > 0].std()
descending_volatility = returns[returns < 0].std()

print(f"Ascending Periods Volatility:\n {ascending_volatility}\n", end=40*"=")
print("\nAscending Periods Average Volatility:\n", ascending_volatility.mean())
print(50*"=")
print(f"Descending Periods Volatility:\n{descending_volatility}\n", end=40*"=")
print("\nDescending Periods Average Volatility:\n", descending_volatility.mean())
# Out:
# Ascending Periods Volatility:
#  BTC-USD     0.020165
# ETH-USD     0.025207
# USDT-USD    0.000259
# XRP-USD     0.025770
# SOL-USD     0.035488
# BNB-USD     0.023851
# DOGE-USD    0.037181
# USDC-USD    0.000106
# ADA-USD     0.027024
# TRX-USD     0.014546
# dtype: float64
# ...
# Ascending Periods Average Volatility:
#  0.020959756459158513
# ...
# Descending Periods Volatility:
# BTC-USD     0.016955
# ETH-USD     0.020512
# USDT-USD    0.000238
# XRP-USD     0.022189
# SOL-USD     0.025732
# BNB-USD     0.018876
# DOGE-USD    0.028003
# USDC-USD    0.000093
# ADA-USD     0.023792
# TRX-USD     0.013218
# dtype: float64
# ...
# Descending Periods Average Volatility:
#  0.016960938244187707
